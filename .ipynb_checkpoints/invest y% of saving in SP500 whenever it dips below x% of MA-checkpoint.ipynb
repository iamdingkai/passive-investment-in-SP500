# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm


from scipy.optimize import fsolve

import yfinance as yf

#########################################
# Download SP500 index from Yahoo Finance

start_date='1985-12-01'
end_date='2021-07-21'

# download S&P500 data from yahoo
sp=yf.download('^GSPC',start=start_date,end=end_date,progress=False)
sp.head()
# calculate 50 day moving average
sp['ma50']=sp['Close'].rolling(50).mean()

plt.figure(num=1,figsize=(10,10))
plt.clf()
plt.subplot(2,1,1)
plt.plot(sp['Close'],'b-',sp['ma50'],'r--')
plt.legend(['raw','ma50'])
plt.grid('minor')
plt.title('SP500 and 50 day MA')

plt.subplot(2,1,2)
plt.plot((sp['Close']/sp['ma50']-1)*100,'b-')
plt.grid('minor')
plt.title('% deviation from 50 day MA')
#########################################
# Out:
# Text(0.5, 1.0, '% deviation from 50 day MA')

# %%
# Assume: $33 of daily income flowing in
# Assume: no interest rate on cash savings

# Investment Method: Wait for x% Dip then Buy with y% Savings
# Varying x and y, calculate annualized returns for all (x,y) combinations
# Investment Horizon: starting date of SP500 to today


# total number of days with income of $33/day
total_days=(pd.to_datetime(sp.index[-1])-pd.to_datetime(sp.index[50])).days+1 


dip1=np.linspace(0,0.15,20) # values of %-dips to try
ishare1=np.linspace(0,0.4,20) # share of saving to buy

sp_shares_bought2=np.zeros((dip1.size,ishare1.size)) # total shares bought so far
total_wealth2=np.zeros((dip1.size,ishare1.size)) # total wealth accumulated at end of investment period
saving2=np.zeros((dip1.size,ishare1.size)) # total cash saving (cumulative labor income saved that is not invested in SP500)
avg_daily_return2=np.zeros((dip1.size,ishare1.size)) # average daily return for the entire investment horizon
avg_daily_return_guess=1+1e-8 # initial guess for average daily return
avg_annual_return2=np.zeros((dip1.size,ishare1.size)) # average annual return for the entire investment horizon

print('dip1.size=',str(dip1.size),'ishare1.size=',str(ishare1.size))

for i_dip,dip in enumerate(dip1): # try different %dips
    
    print('i_dip=',str(i_dip),': invest whenever SP500 dips',str(round(dip*100,2)),'% below its 50-day moving average')

    for i_ishare,ishare in enumerate(ishare1): # try different %saving invested        
        
        print('   i_ishare=',str(i_ishare),': invest',str(round(ishare*100,2)),'% of cumulative saving each time')

        t=pd.to_datetime(sp.index[50]) # date
        end_date=pd.to_datetime(sp.index[-1]) # end date (today)
        
        while t<=end_date: # loop over each day (not just trading days)
            saving2[i_dip,i_ishare]=saving2[i_dip,i_ishare]+33 # add 33 of daily income
            
            # if trading day and stock price dips below dip, then invest
            if t in sp.index and sp.loc[t,'Close']<=sp.loc[t,'ma50']*(1-dip): 
                saving2[i_dip,i_ishare]=saving2[i_dip,i_ishare]*(1-ishare)
                sp_shares_bought2[i_dip,i_ishare]=sp_shares_bought2[i_dip,i_ishare]\
                    +saving2[i_dip,i_ishare]*ishare/sp.loc[t,'Close']
        
            t=t+dt.timedelta(days=1) 
            
        # calculate total wealth (saving+final value of SP500 shares), avg daily return
        total_wealth2[i_dip,i_ishare]=\
            sp_shares_bought2[i_dip,i_ishare]*sp['Close'][-1]+saving2[i_dip,i_ishare]
        avg_daily_return2[i_dip,i_ishare]=\
            fsolve(lambda R:(1-R**total_days)/(1-R)-total_wealth2[i_dip,i_ishare]/33,\
                   x0=avg_daily_return_guess)
        # calculate average annualized return (IRR)
        avg_annual_return2[i_dip,i_ishare]=(np.power(avg_daily_return2[i_dip,i_ishare],365)-1)*100
        
        print('   Resulting an average annual return of',str(round(avg_annual_return2[i_dip,i_ishare],2)),'%')
# Out:
# dip1.size= 20 ishare1.size= 20
# i_dip= 0 : invest whenever SP500 dips 0.0 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 8.12 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 8.13 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 8.06 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.98 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.89 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.8 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.69 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.59 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.48 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 7.37 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 7.25 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 7.14 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 7.01 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.88 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.75 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.61 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.47 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 6.32 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 6.17 %
# i_dip= 1 : invest whenever SP500 dips 0.79 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 8.05 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 8.1 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 8.04 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.96 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.87 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.78 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.68 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.57 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.46 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 7.35 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 7.24 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 7.12 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.99 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.87 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.73 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.6 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.45 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 6.31 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 6.15 %
# i_dip= 2 : invest whenever SP500 dips 1.58 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 7.94 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 8.05 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 8.02 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.95 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.86 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.77 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.67 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.56 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.45 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 7.34 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 7.23 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 7.11 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.98 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.85 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.72 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.44 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 6.29 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 6.14 %
# i_dip= 3 : invest whenever SP500 dips 2.37 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 7.73 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 7.93 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.93 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.88 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.81 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.73 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.63 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.54 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.43 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 7.32 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 7.21 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 7.09 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.97 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.84 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.71 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.44 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 6.29 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 6.14 %
# i_dip= 4 : invest whenever SP500 dips 3.16 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 7.51 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 7.76 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.79 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.76 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.71 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.63 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.55 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.46 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.36 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 7.25 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 7.14 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 7.02 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.9 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.78 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.65 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.51 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.37 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 6.23 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 6.08 %
# i_dip= 5 : invest whenever SP500 dips 3.95 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 7.29 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 7.57 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.62 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.6 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.56 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.5 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.42 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.34 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.25 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 7.15 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 7.04 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.93 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.81 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.69 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.56 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.43 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.29 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 6.15 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 6.0 %
# i_dip= 6 : invest whenever SP500 dips 4.74 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 7.08 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 7.37 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.43 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.41 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.36 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.3 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 7.22 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 7.14 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 7.05 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.95 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.85 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.75 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.63 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.52 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.39 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 6.26 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 6.13 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.99 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.84 %
# i_dip= 7 : invest whenever SP500 dips 5.53 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.94 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 7.21 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.25 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.22 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.15 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.07 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.98 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.88 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.78 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.68 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.57 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.46 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.34 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.22 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 6.1 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.97 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.83 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.69 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.55 %
# i_dip= 8 : invest whenever SP500 dips 6.32 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.83 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 7.12 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.17 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.15 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 7.09 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 7.01 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.92 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.82 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.71 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.6 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.48 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.36 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.23 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.1 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.97 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.83 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.68 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.54 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.38 %
# i_dip= 9 : invest whenever SP500 dips 7.11 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.64 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.95 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 7.02 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 7.02 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.98 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.92 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.84 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.75 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.64 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.53 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.41 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.29 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.16 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.02 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.88 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.74 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.59 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.43 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.27 %
# i_dip= 10 : invest whenever SP500 dips 7.89 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.44 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.76 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.83 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.84 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.81 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.77 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.71 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.64 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.56 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.47 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.37 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.26 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.15 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.03 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.9 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.77 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.62 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.48 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.32 %
# i_dip= 11 : invest whenever SP500 dips 8.68 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.3 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.7 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.77 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.77 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.74 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.7 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.64 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.5 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.42 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.33 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.23 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 6.13 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 6.01 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.89 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.76 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.63 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.49 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.34 %
# i_dip= 12 : invest whenever SP500 dips 9.47 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.2 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.63 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.68 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.66 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.61 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.55 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.49 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.42 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.34 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.26 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.17 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.08 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.98 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.87 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.76 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.64 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.52 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.38 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.24 %
# i_dip= 13 : invest whenever SP500 dips 10.26 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.1 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.59 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.66 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.64 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.52 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.44 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.37 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.28 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.2 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 6.1 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 6.01 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.91 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.8 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.69 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.57 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.45 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.32 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 5.18 %
# i_dip= 14 : invest whenever SP500 dips 11.05 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 6.0 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.55 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.62 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.51 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.42 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.33 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.24 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.14 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.04 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 5.94 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 5.83 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.72 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.61 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.49 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.37 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.24 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.11 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 4.97 %
# i_dip= 15 : invest whenever SP500 dips 11.84 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 5.84 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.52 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.65 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.63 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.56 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.48 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.39 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.29 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.19 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.08 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 5.98 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 5.87 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.75 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.64 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.52 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.39 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.26 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 5.13 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 4.99 %
# i_dip= 16 : invest whenever SP500 dips 12.63 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 5.71 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.46 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.61 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.6 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.53 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.44 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.33 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.22 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.1 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 5.97 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 5.84 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 5.71 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.58 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.44 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.3 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.16 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.01 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 4.85 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 4.69 %
# i_dip= 17 : invest whenever SP500 dips 13.42 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 5.43 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.34 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.62 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.58 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.51 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.42 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.32 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.21 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.1 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 5.97 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 5.85 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.72 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.58 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.44 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.3 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.15 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 4.99 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 4.83 %
# i_dip= 18 : invest whenever SP500 dips 14.21 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 5.24 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.21 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.5 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.56 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.53 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.46 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.38 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.28 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.17 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.05 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 5.93 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 5.8 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.67 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.53 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.39 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.24 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.08 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 4.93 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 4.76 %
# i_dip= 19 : invest whenever SP500 dips 15.0 % below its 50-day moving average
#    i_ishare= 0 : invest 0.0 % of cumulative saving each time
#    Resulting an average annual return of 0.0 %
#    i_ishare= 1 : invest 2.11 % of cumulative saving each time
#    Resulting an average annual return of 5.04 %
#    i_ishare= 2 : invest 4.21 % of cumulative saving each time
#    Resulting an average annual return of 6.08 %
#    i_ishare= 3 : invest 6.32 % of cumulative saving each time
#    Resulting an average annual return of 6.42 %
#    i_ishare= 4 : invest 8.42 % of cumulative saving each time
#    Resulting an average annual return of 6.52 %
#    i_ishare= 5 : invest 10.53 % of cumulative saving each time
#    Resulting an average annual return of 6.52 %
#    i_ishare= 6 : invest 12.63 % of cumulative saving each time
#    Resulting an average annual return of 6.47 %
#    i_ishare= 7 : invest 14.74 % of cumulative saving each time
#    Resulting an average annual return of 6.39 %
#    i_ishare= 8 : invest 16.84 % of cumulative saving each time
#    Resulting an average annual return of 6.3 %
#    i_ishare= 9 : invest 18.95 % of cumulative saving each time
#    Resulting an average annual return of 6.2 %
#    i_ishare= 10 : invest 21.05 % of cumulative saving each time
#    Resulting an average annual return of 6.09 %
#    i_ishare= 11 : invest 23.16 % of cumulative saving each time
#    Resulting an average annual return of 5.97 %
#    i_ishare= 12 : invest 25.26 % of cumulative saving each time
#    Resulting an average annual return of 5.85 %
#    i_ishare= 13 : invest 27.37 % of cumulative saving each time
#    Resulting an average annual return of 5.72 %
#    i_ishare= 14 : invest 29.47 % of cumulative saving each time
#    Resulting an average annual return of 5.58 %
#    i_ishare= 15 : invest 31.58 % of cumulative saving each time
#    Resulting an average annual return of 5.44 %
#    i_ishare= 16 : invest 33.68 % of cumulative saving each time
#    Resulting an average annual return of 5.3 %
#    i_ishare= 17 : invest 35.79 % of cumulative saving each time
#    Resulting an average annual return of 5.14 %
#    i_ishare= 18 : invest 37.89 % of cumulative saving each time
#    Resulting an average annual return of 4.99 %
#    i_ishare= 19 : invest 40.0 % of cumulative saving each time
#    Resulting an average annual return of 4.82 %
# Text(0.5, 0.92, '% average annual return')

# %%
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')

fig=plt.figure(num=3,figsize=(10,10))
plt.clf()
ax=fig.add_subplot(2,2,1,projection='3d')
ax.plot_surface(dip2*100,ishare2*100,total_wealth2/12e3,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('total final wealth')

ax=fig.add_subplot(2,2,2,projection='3d')
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')
ax.plot_surface(dip2*100,ishare2*100,sp_shares_bought2*sp['Close'][-1]/12e3,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('total final wealth in stock')

ax=fig.add_subplot(2,2,3,projection='3d')
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')
ax.plot_surface(dip2*100,ishare2*100,saving2/12e3,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('total final wealth in cash saving')

ax=fig.add_subplot(2,2,4,projection='3d')
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')
ax.plot_surface(dip2*100,ishare2*100,avg_annual_return2,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('% average annual return')


# figure out best %dip and best %invest
[best_dip_idx,best_ishare_idx]=np.unravel_index(avg_annual_return2.argmax(),avg_annual_return2.shape)
print('Best to wait for a',str(round(dip1[best_dip_idx]*100,2)),'% dip in SP500 below its 50-day MA')
print('When those dips happen, buy SP500 with',str(round(ishare1[best_ishare_idx]*100,2)),'% cumulative cash saved up')
print('Resulting annualized return =',str(round(avg_annual_return2[best_dip_idx,best_ishare_idx],2)),'% based on historical data.')
# Out:
# Best to wait for a 0.0 % dip in SP500 below its 50-day MA
# When those dips happen, buy SP500 with 4.21 % cumulative cash saved up
# Resulting annualized return = 8.13 % based on historical data.
