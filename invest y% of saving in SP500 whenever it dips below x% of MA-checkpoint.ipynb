# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm


from scipy.optimize import fsolve

import yfinance as yf

#########################################
# Download SP500 index from Yahoo Finance

start_date='1985-12-01'
end_date='2021-07-21'

# download S&P500 data from yahoo
sp=yf.download('^GSPC',start=start_date,end=end_date,progress=False)
sp.head()

# calculate 50 day moving average
sp['ma50']=sp['Close'].rolling(50).mean()

plt.figure(num=1,figsize=(10,10))
plt.clf()
plt.subplot(2,1,1)
plt.plot(sp['Close'],'b-',sp['ma50'],'r--')
plt.legend(['raw','ma50'])
plt.grid('minor')
plt.title('SP500 and 50 day MA')

plt.subplot(2,1,2)
plt.plot((sp['Close']/sp['ma50']-1)*100,'b-')
plt.grid('minor')
plt.title('% deviation from 50 day MA')
#########################################
# Out:
# Text(0.5, 1.0, '% deviation from 50 day MA')

# %%
# Assume: $33 of daily income flowing in
# Assume: no interest rate on cash savings

# Investment Method: Wait for x% Dip then Buy with y% Savings
# Varying x and y, calculate annualized returns for all (x,y) combinations
# Investment Horizon: starting date of SP500 to today


# total number of days with income of $33/day
total_days=(pd.to_datetime(sp.index[-1])-pd.to_datetime(sp.index[50])).days+1 


dip1=np.linspace(-0.3,0.3,30) # values of %-dips to try
ishare1=np.linspace(0,0.3,20) # share of saving to buy

sp_shares_bought2=np.zeros((dip1.size,ishare1.size)) # total shares bought so far
total_wealth2=np.zeros((dip1.size,ishare1.size)) # total wealth accumulated at end of investment period
saving2=np.zeros((dip1.size,ishare1.size)) # total cash saving (cumulative labor income saved that is not invested in SP500)
avg_daily_return2=np.zeros((dip1.size,ishare1.size)) # average daily return for the entire investment horizon
avg_daily_return_guess=1+1e-8 # initial guess for average daily return
avg_annual_return2=np.zeros((dip1.size,ishare1.size)) # average annual return for the entire investment horizon

print('dip1.size=',str(dip1.size),'ishare1.size=',str(ishare1.size))

for i_dip,dip in enumerate(dip1): # try different %dips
    
    print('i_dip=',str(i_dip),': invest whenever SP500 dips',str(round(dip*100,0)),'% below its 50-day moving average')

    for i_ishare,ishare in enumerate(ishare1): # try different %saving invested        
        
        print('   i_ishare=',str(i_ishare),': invest',str(round(ishare*100,0)),'% of cumulative saving each time')

        t=pd.to_datetime(sp.index[50]) # date
        end_date=pd.to_datetime(sp.index[-1]) # end date (today)
        
        while t<=end_date: # loop over each day (not just trading days)
            saving2[i_dip,i_ishare]=saving2[i_dip,i_ishare]+33 # add 33 of daily income
            
            # if trading day and stock price dips below dip, then invest
            if t in sp.index and sp.loc[t,'Close']<=sp.loc[t,'ma50']*(1-dip): 
                saving2[i_dip,i_ishare]=saving2[i_dip,i_ishare]*(1-ishare)
                sp_shares_bought2[i_dip,i_ishare]=sp_shares_bought2[i_dip,i_ishare]\
                    +saving2[i_dip,i_ishare]*ishare/sp.loc[t,'Close']
        
            t=t+dt.timedelta(days=1) 
            
        # calculate total wealth (saving+final value of SP500 shares), avg daily return
        total_wealth2[i_dip,i_ishare]=\
            sp_shares_bought2[i_dip,i_ishare]*sp['Close'][-1]+saving2[i_dip,i_ishare]
        avg_daily_return2[i_dip,i_ishare]=\
            fsolve(lambda R:(1-R**total_days)/(1-R)-total_wealth2[i_dip,i_ishare]/33,\
                   x0=avg_daily_return_guess)
        # calculate average annualized return (IRR)
        avg_annual_return2[i_dip,i_ishare]=(np.power(avg_daily_return2[i_dip,i_ishare],365)-1)*100
        
        print('   Resulting an average annual return of',str(round(avg_annual_return2[i_dip,i_ishare],0)),'%')
# Out:
# dip1.size= 30 ishare1.size= 20
# i_dip= 0 : invest whenever SP500 dips -30.0 % below its 50-day moving average
# i_dip= 1 : invest whenever SP500 dips -27.93 % below its 50-day moving average
# i_dip= 2 : invest whenever SP500 dips -25.86 % below its 50-day moving average
# i_dip= 3 : invest whenever SP500 dips -23.79 % below its 50-day moving average
# i_dip= 4 : invest whenever SP500 dips -21.72 % below its 50-day moving average
# i_dip= 5 : invest whenever SP500 dips -19.66 % below its 50-day moving average
# i_dip= 6 : invest whenever SP500 dips -17.59 % below its 50-day moving average
# i_dip= 7 : invest whenever SP500 dips -15.52 % below its 50-day moving average
# i_dip= 8 : invest whenever SP500 dips -13.45 % below its 50-day moving average
# i_dip= 9 : invest whenever SP500 dips -11.38 % below its 50-day moving average
# i_dip= 10 : invest whenever SP500 dips -9.31 % below its 50-day moving average
# i_dip= 11 : invest whenever SP500 dips -7.24 % below its 50-day moving average
# i_dip= 12 : invest whenever SP500 dips -5.17 % below its 50-day moving average
# i_dip= 13 : invest whenever SP500 dips -3.1 % below its 50-day moving average
# i_dip= 14 : invest whenever SP500 dips -1.03 % below its 50-day moving average
# i_dip= 15 : invest whenever SP500 dips 1.03 % below its 50-day moving average
# i_dip= 16 : invest whenever SP500 dips 3.1 % below its 50-day moving average
# i_dip= 17 : invest whenever SP500 dips 5.17 % below its 50-day moving average
# i_dip= 18 : invest whenever SP500 dips 7.24 % below its 50-day moving average
# i_dip= 19 : invest whenever SP500 dips 9.31 % below its 50-day moving average
# i_dip= 20 : invest whenever SP500 dips 11.38 % below its 50-day moving average
# i_dip= 21 : invest whenever SP500 dips 13.45 % below its 50-day moving average
# i_dip= 22 : invest whenever SP500 dips 15.52 % below its 50-day moving average
# i_dip= 23 : invest whenever SP500 dips 17.59 % below its 50-day moving average
# i_dip= 24 : invest whenever SP500 dips 19.66 % below its 50-day moving average
# i_dip= 25 : invest whenever SP500 dips 21.72 % below its 50-day moving average
# i_dip= 26 : invest whenever SP500 dips 23.79 % below its 50-day moving average
# i_dip= 27 : invest whenever SP500 dips 25.86 % below its 50-day moving average
# i_dip= 28 : invest whenever SP500 dips 27.93 % below its 50-day moving average
# i_dip= 29 : invest whenever SP500 dips 30.0 % below its 50-day moving average

# %%
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')

fig=plt.figure(num=3,figsize=(10,10))
plt.clf()
ax=fig.add_subplot(2,2,1,projection='3d')
ax.plot_surface(dip2*100,ishare2*100,total_wealth2/12e3,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('total final wealth')

ax=fig.add_subplot(2,2,2,projection='3d')
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')
ax.plot_surface(dip2*100,ishare2*100,sp_shares_bought2*sp['Close'][-1]/12e3,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('total final wealth in stock')

ax=fig.add_subplot(2,2,3,projection='3d')
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')
ax.plot_surface(dip2*100,ishare2*100,saving2/12e3,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('total final wealth in cash saving')

ax=fig.add_subplot(2,2,4,projection='3d')
dip2,ishare2=np.meshgrid(dip1,ishare1,indexing='ij')
ax.plot_surface(dip2*100,ishare2*100,avg_annual_return2,cmap=cm.hsv)
ax.set_xlabel('% below MA50 to invest')
ax.set_ylabel('% of cumulative saving to buy SP500')
ax.set_zlabel('over annual income')
ax.set_title('% average annual return')


# figure out best %dip and best %invest
[best_dip_idx,best_ishare_idx]=np.unravel_index(avg_annual_return2.argmax(),avg_annual_return2.shape)
print('Best to wait for a',str(round(dip1[best_dip_idx]*100,2)),'% dip in SP500 below its 50-day MA')
print('When those dips happen, buy SP500 with',str(round(ishare1[best_ishare_idx]*100,2)),'% cumulative cash saved up')
print('Resulting annualized return =',str(round(avg_annual_return2[best_dip_idx,best_ishare_idx],2)),'% based on historical data.')
# Out:
# Best to wait for a -30.0 % dip in SP500 below its 50-day MA
# When those dips happen, buy SP500 with 1.58 % cumulative cash saved up
# Resulting annualized return = 8.27 % based on historical data.
